# %%
noun = 'Noun'
noun2 = 'Second Noun'
plno = 'Plural Noun'
verb = 'Verb'
pave = 'Past Tense Verb'
adj = 'Adjective'
adj2 = 'Second Adjective'
adj3 = 'Third Adjective'
adj4 = 'Fourth Adjective'
animal = 'Animal'
cont = 'A container'
body = 'Part of the Body'
moon1 = 'Noun that rhymes with Moon'
moon2 = 'Second Noun that rhymes with Moon'
day = 'Noun that rhymes with Day'
inst = 'Instrument'
vege = 'Vegetable'
place = 'Place'
occ = 'Occupation'
    
Puzzle = []
Input = []
    
Puzzle.append("""
Old Mother Hubbard went to the {}
to get her {} {} a bone.
When she got there, the {} was {},
And so her {} {} had none.
""")
    
Input.append([noun, adj, 'Animal', noun, adj2, adj3, 'Animal'])
    
Puzzle.append("""
Jack and Jill went up to the {}
to fetch a {} of water.
Jack fell down and broke his {}
And Jill came tumbling after.
""")
              
Input.append([noun, 'A container', noun2])
              
Puzzle.append("""
There was a girl, and she had a little curl
Right in the middle of her {}
And when she was {}, she was very, very {}
And when she was bad, she was {} .
""")
    
Input.append([adj, adj2, adj3, 'Part of the Body'])
    
Puzzle.append("""
There was a {} woman
Who {} in a shoe.
She had so many {},
she didn't know what to do.
""")
    
Input.append([adj, 'Past Tense Verb', 'Plural Noun'])
    
Puzzle.append("""
Hi, diddle, diddle, the {} and the fiddle,
The {} jumped over the {} .
The little dog laughed to see such sport,
And the dish ran away with the {} .
""")

Input.append([noun, animal, moon1, moon2])
    
Puzzle.append("""
Little Miss Muffet sat on a {}
Eating her curds and {} .
Along came an {} and sat down beside her
And frightened Miss Muffet away.
""")
    
Input.append([noun, day, animal])
    
Puzzle.append("""
Little Boy Blue come blow your {}
The sheep's in the {} , the cow's in the {}.
Where is the {} boy who looks after the sheep?
He's under the {} fast asleep.
""")
    
Input.append([inst, place, vege, adj, noun])
    
Puzzle.append("""
Mary had a little {}
Its {} was white as snow.
And everywhere that Mary went
Her {} was sure to {} .
""")
    
Input.append([animal, noun, animal, verb])
    
Puzzle.append("""
Three {} mice. See how they run!
They all ran after the farmer's {} ,
Who cut off their {} with a carving {} .
Did you ever see such a sight in your life as three {} mice?
""")
    
Input.append([adj, occ, plno, noun, adj])
    
Puzzle.append("""
There was a crooked man, and he went an {} mile.
He found a {} against an {} stile.
He bought an {} cat, which caught an {} mouse,
And they all lived together in a little crooked {}
""")
    
Input.append([adj, noun, adj2, adj3, adj4, noun2])
    
def get_values(parts_of_speech):
    words = []
    for i in parts_of_speech:
        words.append(input("Input {}\n".format(i)))
    return words
    
def put_in_string(string, parts_of_speech):
    keyWords = get_values(parts_of_speech)
    temp = string
    temp = temp.format(*keyWords)
    return temp
    
for i in range(len(Puzzle)):
    print('Mad Lib #{}'.format(i+1))
    print(put_in_string(Puzzle[i], Input[i]))
